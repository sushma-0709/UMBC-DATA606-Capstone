# %%
import pandas as pd

# %%
df_inputs=pd.read_csv("../data/blockchair_litecoin_inputs_20250908.tsv",sep='\t')

# %%
df_inputs.head(5)
# Out:
#    block_id                                   transaction_hash  index  \
# 0   2964088  f8d8a148b641c3b39edc6c60e90c48901f65e86909c295...      1
# 1   2964091  f28a953de3e2762efcb49867684c4b046358dbc0925e1b...      1
# 2   2962407  e876a69574cbc0ea49434b9b4c1f7450f6734c4d1baf1e...      2
# 3   2964088  8cad07650f9e5b8a96776d2107427975b059a50619382d...     19
# 4   2964088  2e2e2eaf6fbf1702ff75a3c1d3c59d3de6651af9bfeb34...      0
#
#                   time      value  value_usd  \
# 0  2025-09-07 23:53:06  429558365   481.9215
# 1  2025-09-07 23:55:45  775504822   870.0389
# 2  2025-09-05 00:37:43   18023670    20.0531
# 3  2025-09-07 23:53:06    2637650     2.9592
# 4  2025-09-07 23:53:06  175659200   197.0721
#
#                                      recipient                   type  \
# 0           MHEhpP2jcSrvZQQbEHHKPw26bCqk1DaYgn             scripthash
# 1  ltc1qpa3gse2xnah37r7upjyvrxfx572gr53uduu275  witness_v0_scripthash
# ...

# %%
df_inputs.columns
# Out:
# Index(['block_id', 'transaction_hash', 'index', 'time', 'value', 'value_usd',
#        'recipient', 'type', 'script_hex', 'is_from_coinbase', 'is_spendable',
#        'spending_block_id', 'spending_transaction_hash', 'spending_index',
#        'spending_time', 'spending_value_usd', 'spending_sequence',
#        'spending_signature_hex', 'spending_witness', 'lifespan', 'cdd'],
#       dtype='object')
