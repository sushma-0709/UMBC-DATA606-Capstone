# %%
import pandas as pd

# %%
df_transactions=pd.read_csv("../data/blockchair_litecoin_transactions_20250908.tsv",sep='\t')

# %%
df_transactions.head(5)
# Out:
#    block_id                                               hash  \
# 0   2964092  f73497dcb5c1f7791ec03fdbdec5768ee8079588b9a9fb...
# 1   2964092  8a75569c7fb3e863bf63ed16ec1cae3ff956d30657d472...
# 2   2964092  8b3cfc932d02662f462a295732b11aad1c67e1ba0e0640...
# 3   2964092  c6a8d013a7911c00457ddf8cd827c8e5841e15b79fd863...
# 4   2964092  87716be43e496f7801e54916c5200329d69f02fdf31e61...
#
#                   time  size  weight  version   lock_time  is_coinbase  \
# 0  2025-09-08 00:01:45   268     964        1  1172964361            1
# 1  2025-09-08 00:01:45   248     664        1           0            0
# 2  2025-09-08 00:01:45   206     496        2           0            0
# 3  2025-09-08 00:01:45   223     568        2     2964021            0
# 4  2025-09-08 00:01:45   880    1920        1           0            0
#
#    has_witness  input_count  ...  input_total_usd  output_total  \
# 0            1            1  ...           0.0000     633000494
# ...

# %%
df_transactions.columns
# Out:
# Index(['block_id', 'hash', 'time', 'size', 'weight', 'version', 'lock_time',
#        'is_coinbase', 'has_witness', 'input_count', 'output_count',
#        'input_total', 'input_total_usd', 'output_total', 'output_total_usd',
#        'fee', 'fee_usd', 'fee_per_kb', 'fee_per_kb_usd', 'fee_per_kwu',
#        'fee_per_kwu_usd', 'cdd_total'],
#       dtype='object')
