# %%
import pandas as pd

# %%
df_outputs=pd.read_csv("../data/blockchair_litecoin_outputs_20250908.tsv",sep='\t')

# %%
df_outputs.head(5)
# Out:
#    block_id                                   transaction_hash  index  \
# 0   2964092  f73497dcb5c1f7791ec03fdbdec5768ee8079588b9a9fb...      0
# 1   2964092  f73497dcb5c1f7791ec03fdbdec5768ee8079588b9a9fb...      0
# 2   2964092  f73497dcb5c1f7791ec03fdbdec5768ee8079588b9a9fb...      0
# 3   2964092  f73497dcb5c1f7791ec03fdbdec5768ee8079588b9a9fb...      1
# 4   2964092  8a75569c7fb3e863bf63ed16ec1cae3ff956d30657d472...      0
#
#                   time      value  value_usd  \
# 0  2025-09-08 00:01:45  633000494   727.8873
# 1  2025-09-08 00:01:45  633000494   727.8873
# 2  2025-09-08 00:01:45  633000494   727.8873
# 3  2025-09-08 00:01:45          0     0.0000
# 4  2025-09-08 00:01:45   11851000    13.6275
#
#                             recipient        type  \
# 0  LfdYLbP9F9CpmCX6atZnHZb8KkS8T6x4DK  pubkeyhash
# 1  LfdYLbP9F9CpmCX6atZnHZb8KkS8T6x4DK  pubkeyhash
# 2  LfdYLbP9F9CpmCX6atZnHZb8KkS8T6x4DK  pubkeyhash
# 3  d-b4c5ab409bdf398c2075ff0a1cf6c244    nulldata
# ...

# %%
df_outputs.columns
# Out:
# Index(['block_id', 'transaction_hash', 'index', 'time', 'value', 'value_usd',
#        'recipient', 'type', 'script_hex', 'is_from_coinbase', 'is_spendable'],
#       dtype='object')
